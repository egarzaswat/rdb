# %%
#this defaults plots to matplotlib 1.0 formatting
import matplotlib.style
import matplotlib as mpl
#mpl.style.use('classic')
# %matplotlib inline
mpl.rcParams['figure.dpi']= 150

# importing packages needed to run this script 
from subprocess import call
import pickle as pickle
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.cluster.hierarchy as sch

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import copy
import colorsys
import matplotlib.image as mpimg
from IPython.display import display
from IPython.display import Image
import scipy.cluster.hierarchy as sch
from scipy.stats import scoreatpercentile 
from pysca import scaTools as sca
# import mpld3
import pickle as pickle
from optparse import OptionParser
import sys
sys.path.append('../utilities/')
sys.path.append('..')

from graph_helpers import (
   gen_amino_acid_position_in_ref_sequence_graph,
   gen_clustered_similarity_matrix, 
   gen_unclustered_similarity_matrix,
   gen_pairwise_sequence_identities
)
from helpers import (
    show_processmsa_results,
    seq_count_check
)

# %matplotlib inline

if not os.path.exists('../output/'):
    os.makedirs('../output/')

# %%
input_pfam = '/home/bjohnson/rdb/notebooks/Insig1/bacterial_insig_dealign_shortened.txt'
output_pfam = '/home/bjohnson/rdb/notebooks/Insig1/bacterial_insig_dealign_shortened-annotated.txt'
pfam_seq = '/home/bjohnson/rdb/common/pfamseq.txt'

# %%
command = 'scaProcessMSA --help'
call(command, shell = True)
# Out:
# usage: scaProcessMSA [-h] -a ALIGNMENT [-d DESTINATION] [-s PDBID] [-b PDBDIR]
#                      [-c CHAINID] [-f SPECIES] [-r REFSEQ] [-o REFPOS]
#                      [-i I_REF]
#                      [-p PARAMETERS PARAMETERS PARAMETERS PARAMETERS] [-n]
#                      [-t] [-m]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a ALIGNMENT, --alignment ALIGNMENT
#                         Input Sequence Alignment
#   -d DESTINATION, --dest DESTINATION
#                         specify an output directory
#   -s PDBID, --pdb PDBID
#                         PDB identifier (ex: 1RX2)
#   -b PDBDIR, --pdbdir PDBDIR
#                         directory where PDBs are stored
#   -c CHAINID, --chainID CHAINID
#                         chain ID in the PDB for the reference sequence
#   -f SPECIES, --species SPECIES
#                         species of the reference sequence
#   -r REFSEQ, --refseq REFSEQ
# ...

# %%
#construct a dictionary of phylogenetic groups
sca.AnnotPfam(input_pfam, output_pfam, pfam_seq=pfam_seq)
print('Executed')
# Out:
# Beginning annotation
# Current step 0, key sp|A1T557|INSIG_MYCVP INSIG protein homolog OS=Mycolicibacterium vanbaalenii (strain DSM 7251
# Error: 'sp|A1T557|INSIG_MYCVP INSIG protein homolog OS=Mycolicibacterium vanbaalenii (strain DSM 7251 '
# Current step 1, key A0A0G4LTK5
# Error: 'A0A0G4LTK5'
# Current step 2, key A0A0G4LTK5
# Error: 'A0A0G4LTK5'
# Current step 3, key T0JUU4
# Error: 'T0JUU4'
# Current step 4, key G2R9T8
# Error: 'G2R9T8'
# Current step 5, key L2GHS1
# Error: 'L2GHS1'
# Current step 6, key A0A7J6JNM6
# Error: 'A0A7J6JNM6'
# Current step 7, key E3QR22
# Error: 'E3QR22'
# Current step 8, key A0A446BUU4
# Error: 'A0A446BUU4'
# Current step 9, key A0A1S1VRJ3
# Error: 'A0A1S1VRJ3'
# Current step 10, key A0A167ACX0
# Error: 'A0A167ACX0'
# Current step 11, key A0A4U6XUM6
# Error: 'A0A4U6XUM6'
# Current step 12, key A0A166SKI3
# Error: 'A0A166SKI3'
# Current step 13, key A0A1G4AUI1
# Error: 'A0A1G4AUI1'
# Current step 14, key Q2H703
# Error: 'Q2H703'
# ...

# %%
path2aln_processed = '/home/bjohnson/rdb/data/bacterial_insig_aligned-annotated.txt'


# determine index of the reference sequence (homo sapiens)
for ix, line in enumerate(open(path2aln_processed,'r').readlines()): # LOOK THROUGH EACH LINE TO FIGURE OUT RELEVANT SEQUENCE    
    if 'Myco' in line:
        print(line)
    if line[0] == '>':
        
        if 'Mycobacterium vanbaalenii' in line: # CHANGE STRING TO WHATEVER YOU WANT 
            print("here")
                        
            if '>INSI2_HUMAN|' in line: #FILTER THE STRING FURTHER IF YOU WANT. CAN DELETE OR ADD MORE IF STATEMENTS TO FILTER 
                
                referenceSeq_ix = ix #INDEX OF THE SEQUENCE ANNOTATION. IX+1 WILL GIVE YOU INDEX OF THE SEQUENCE ITSELF                
                break

# PRING OUT RELEVANT REFERENCE SEQUENCE AND ITS ANNOTATION
print('####### THE RELEVANT SEQUENCE YOU CARE ABOUT BELOW:   ######')
print([line for line in open(path2aln_processed,'r').readlines()[referenceSeq_ix:referenceSeq_ix+2]])

# %%
path2out = '../output/'
command =  str('scaProcessMSA -a %s -d %s -i %s' % (path2aln_processed, path2out, referenceSeq_ix))
print(command)
call(command,shell = 'True')
print("Executed")

# %%
dbname = "Insig1pfamalign-annotated.db"
pickle_path = '/home/bjohnson/rdb/output/Insig1pfamalign-annotated.db'
db = pickle.load(open(pickle_path,'rb'))
Dseq = db['sequence']

# %%
show_processmsa_results(Dseq)
# Out:
# *****Final processed alignment parameters****
# Number of sequences: M = 956
# Number of effective sequences: M' = 154
# Number of alignment positions: L = 177
# Number of positions in the ats: 177
# Number of structure positions mapped: 177
# Missing key distmat
# ****************************************

# %%
# check for sufficient sequences in alignment
seq_count_check(Dseq)
# Out:
# The number of effective sequences in this MSA is: 154
# This alignment has a sufficient number of effective sequences for analysis with SCA.
# Npos (L) = 177

# %%
# Apply scaCore to our processed alignment 
command = 'scaCore -i %s' % (pickle_path)
print (command)
call(command, shell = 'True')
db = pickle.load(open(pickle_path,'rb'))
Dsca = db['sca']
print("Executed")
# Out:
# scaCore -i /home/bjohnson/rdb/output/Insig1pfamalign-annotated.db
# Computing the sequence projections.
# Computing sequence similarity matrix.
# Computing the SCA conservation and correlation values.
# Computing matrix randomizations...
# Randomizations complete, 10 trials, time: 0.9 minutes
# Calculations complete, writing to database file /home/bjohnson/rdb/output/Insig1pfamalign-annotated
# Executed

# %%
# run scaSectorID 
command = 'scaSectorID -i %s' % (pickle_path)
print (command)
call(command, shell = 'True')

# Load and store results of scaSectorID
db = pickle.load(open(pickle_path,'rb'))
Dsect = db['sector'] 
print("Executed")
# Out:
# scaSectorID -i /home/bjohnson/rdb/output/Insig1pfamalign-annotated.db
# Selected kpos=6 significant eigenmodes.
# Calculations complete, writing to database file /home/bjohnson/rdb/output/Insig1pfamalign-annotated
# Executed
