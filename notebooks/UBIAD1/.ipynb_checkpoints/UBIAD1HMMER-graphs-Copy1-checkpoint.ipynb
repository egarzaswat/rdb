# %%
#this defaults plots to matplotlib 1.0 formatting
import matplotlib.style
import matplotlib as mpl
#mpl.style.use('classic')
# %matplotlib inline
mpl.rcParams['figure.dpi']= 150

# importing packages needed to run this script 
from subprocess import call
import pickle as pickle
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.cluster.hierarchy as sch

import os
import time
import matplotlib.pyplot as plt
import numpy as np
import copy
import colorsys
from math import floor

import matplotlib.image as mpimg
from IPython.display import display
from IPython.display import Image
import scipy.cluster.hierarchy as sch
from scipy.stats import scoreatpercentile 
import scipy.stats as stats
# import mpld3
import pickle as pickle
from optparse import OptionParser
import sys
sys.path.append('../../utilities')
sys.path.append('..')
from pysca import scaTools as sca
from graph_helpers import (
   gen_amino_acid_position_in_ref_sequence_graph,
   gen_clustered_similarity_matrix, 
   gen_unclustered_similarity_matrix,
   gen_pairwise_sequence_identities,
   gen_eigenvalues_graph
)
from helpers import (
    show_processmsa_results,
    seq_count_check
)

# %matplotlib inline

if not os.path.exists('../output/'):
    os.makedirs('../output/')

# %%
pickle_path = '/home/bjohnson/rdb/notebooks/UBIAD1/UBIAD1alignedsanitizedfasta.db'
db = pickle.load(open(pickle_path,'rb'))
Dseq = db['sequence']
Dsca = db['sca']
Dsect = db['sector'] if db['sector'] else None

# %%
#check similarity matrix
gen_unclustered_similarity_matrix(title="Unclustered",Dsca=[Dsca])

# %%
gen_clustered_similarity_matrix(title="Clustered", Dsca=[Dsca])

# %%
#Visualizing evolutionary conservation
gen_amino_acid_position_in_ref_sequence_graph(
    xlabel='amino acid position in reference sequence', 
    Dsca=[Dsca], 
    Dseq=[Dseq]
)

# %%
gen_pairwise_sequence_identities([Dseq],[Dsca])

# %%
### initialize variables for visualizing the SCA matrix ######

sca_matrix = Dsca['Csca'] #pull out Cij matrix

minCorrelation = 0
maxCorrelation = 1.4

title = '$\~C_{ij}$,\n' # change title of figure to whatever you want
###############################################################

plt.figure()
plt.title(title)
plt.imshow(sca_matrix,cmap = 'jet',vmin=minCorrelation,vmax=maxCorrelation,interpolation='none',aspect='equal')

plt.xlabel('amino acid position') #inserts legend
plt.ylabel('amino acid position')

plt.xticks(np.arange(0,len(Dseq['ats']),50)) #places an xtick every 50 positions on this axis
plt.yticks(np.arange(0,len(Dseq['ats']),50))

plt.colorbar() # Shows the legend

plt.figure()
plt.title('Cij_randomized')
plt.imshow(Dsca['Crand'], cmap = 'jet', vmin = minCorrelation, vmax = maxCorrelation, interpolation = 'none', aspect = 'equal')

plt.xlabel('amino acid position') #inserts legend
plt.ylabel('amino acid position')

plt.xticks(np.arange(0,len(Dseq['ats']),50)) #places an xtick every 50 positions on this axis
plt.yticks(np.arange(0,len(Dseq['ats']),50))

plt.colorbar() # Shows the legend


###############################################################
plt.figure()
#distribution of eigenvalues
hist0, bins = np.histogram(Dsca['Lrand'].flatten(), bins=Dseq['Npos'],range=(0,Dsect['Lsca'].max()))

hist1, bins = np.histogram(Dsect['Lsca'], bins=Dseq['Npos'],range=(0,Dsect['Lsca'].max()))

plt.bar(bins[:-1], hist1, np.diff(bins),color='c',edgecolor = 'k',linewidth = 0.2) #dist of eigenvalues

plt.plot(bins[:-1], hist0/Dsca['Ntrials'], 'r', linewidth=1)

plt.xlabel('Eigenvalues', fontsize=10)
plt.ylabel('Numbers', fontsize=10)

print('Number of eigenmodes to keep is %i' %(Dsect['kpos'])) #Dsect['kpos'] stores number of significant eigenmodes

#This is hard to see so zoom in
#plt.ylim(-0.5,5) #comment if you want to see the whole thing
#plt.xlim()

print ('')
print('cyan - distribution of eigenvalues of SCA matrix')
print('red - distribution of eigenvalues from decomposition of randomized matrix')
# Out:
# Number of eigenmodes to keep is 9
#
# cyan - distribution of eigenvalues of SCA matrix
# red - distribution of eigenvalues from decomposition of randomized matrix

# %%
gen_eigenvalues_graph([Dseq],[Dsca],[Dsect])
# Out:
# Number of eigenmodes to keep is 9

# %%
annot = dict()
for i, h in enumerate(Dseq['hd']):
    try:
        hs = h.split('|')
        annot[hs[0]] = sca.Annot(hs[1], hs[2], hs[3].replace('.',''))
        print(hs[3])
    except:
        print(f"Failed to parse {h}")
# Out:
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Mammalia,Eutheria,Euarchontoglires,Primates,Haplorrhini,Catarrhini,Hominidae,Homo.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Mammalia,Eutheria,Laurasiatheria,Artiodactyla,Tylopoda,Camelidae,Camelus.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Mammalia,Eutheria,Euarchontoglires,Glires,Rodentia,Myomorpha,Muroidea,Muridae,Murinae,Mus,Mus.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Mammalia,Eutheria,Euarchontoglires,Glires,Rodentia,Myomorpha,Muroidea,Muridae,Murinae,Rattus.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Archelosauria,Archosauria,Dinosauria,Saurischia,Theropoda,Coelurosauria,Aves,Neognathae,Galloanserae,Galliformes,Phasianidae,Phasianinae,Gallus.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Amphibia,Batrachia,Anura,Pipoidea,Pipidae,Xenopodinae,Xenopus,Silurana.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Lepidosauria,Squamata,Bifurcata,Unidentata,Episquamata,Toxicofera,Serpentes,Colubroidea,Elapidae,Elapinae,Ophiophagus.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Actinopterygii,Chondrostei,Acipenseriformes,Acipenseridae,Acipenser.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Chondrichthyes,Holocephali,Chimaeriformes,Callorhinchidae,Callorhinchus.
# Eukaryota,Metazoa,Chordata,Craniata,Vertebrata,Euteleostomi,Actinopterygii,Neopterygii,Teleostei,Ostariophysi,Cypriniformes,Danionidae,Danioninae,Danio.
# Eukaryota,Metazoa,Chordata,Cephalochordata,Leptocardii,Amphioxiformes,Branchiostomidae,Branchiostoma.
# Eukaryota,Metazoa,Echinodermata,Eleutherozoa,Echinozoa,Echinoidea,Euechinoidea,Echinacea,Camarodonta,Echinidea,Strongylocentrotidae,Strongylocentrotus.
# Eukaryota,Metazoa,Cnidaria,Anthozoa,Hexacorallia,Actiniaria,Edwardsiidae,Nematostella.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Crustacea,Multicrustacea,Malacostraca,Eumalacostraca,Eucarida,Decapoda,Pleocyemata,Brachyura,Eubrachyura,Portunoidea,Portunidae,Portunus.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Brachiopoda,Linguliformea,Lingulata,Lingulida,Linguloidea,Lingulidae,Lingula.
# Eukaryota,Metazoa,Cnidaria,Anthozoa,Hexacorallia,Actiniaria,Actiniidae,Actinia.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Mollusca,Gastropoda,Caenogastropoda,Architaenioglossa,Ampullarioidea,Ampullariidae,Pomacea.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Paraneoptera,Psocodea,Phthiraptera,Anoplura,Pediculidae,Pediculus.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Coleoptera,Polyphaga,Cucujiformia,Tenebrionidae,Tenebrionidae incertae sedis,Tribolium.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Crustacea,Multicrustacea,Malacostraca,Eumalacostraca,Peracarida,Isopoda,Oniscidea,Crinocheta,Armadillidiidae,Armadillidium.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Mollusca,Bivalvia,Autobranchia,Pteriomorphia,Mytiloida,Mytiloidea,Mytilidae,Mytilinae,Mytilus.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Mollusca,Bivalvia,Autobranchia,Pteriomorphia,Pectinida,Pectinoidea,Pectinidae,Mizuhopecten.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Coleoptera,Polyphaga,Cucujiformia,Chrysomeloidea,Chrysomelidae,Bruchinae,Bruchini,Callosobruchus.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Polyneoptera,Dictyoptera,Blattodea,Blaberoidea,Ectobiidae,Blattellinae,Blattella.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Polyneoptera,Dictyoptera,Blattodea,Blattoidea,Termitoidae,Rhinotermitidae,Coptotermes.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Annelida,Polychaeta,Sedentaria,Scolecida,Capitellidae,Capitella.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Mollusca,Gastropoda,Patellogastropoda,Lottioidea,Lottiidae,Lottia.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Coleoptera,Polyphaga,Cucujiformia,Tenebrionidae,Pimeliinae,Asbolus.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Paraneoptera,Hemiptera,Heteroptera,Panheteroptera,Cimicomorpha,Miridae,Mirini,Apolygus.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Paraneoptera,Hemiptera,Heteroptera,Panheteroptera,Cimicomorpha,Miridae,Dicyphina,Nesidiocoris.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Paraneoptera,Hemiptera,Auchenorrhyncha,Fulgoroidea,Delphacidae,Criomorphinae,Laodelphax.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Coleoptera,Polyphaga,Scarabaeiformia,Scarabaeidae,Dynastinae,Oryctes.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Mollusca,Gastropoda,Heterobranchia,Euthyneura,Panpulmonata,Sacoglossa,Placobranchoidea,Plakobranchidae,Elysia.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Mollusca,Gastropoda,Heterobranchia,Euthyneura,Panpulmonata,Sacoglossa,Placobranchoidea,Plakobranchidae,Elysia.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Hymenoptera,Apocrita,Aculeata,Apoidea,Apidae,Apis.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Lepidoptera,Glossata,Ditrysia,Bombycoidea,Bombycidae,Bombycinae,Bombyx.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Paraneoptera,Thysanoptera,Terebrantia,Thripoidea,Thripidae,Thrips.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Diptera,Brachycera,Muscomorpha,Ephydroidea,Drosophilidae,Drosophila,Sophophora.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Diptera,Nematocera,Culicoidea,Culicidae,Anophelinae,Anopheles.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Mollusca,Cephalopoda,Coleoidea,Octopodiformes,Octopoda,Incirrata,Octopodidae,Octopus.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Chelicerata,Arachnida,Acari,Acariformes,Trombidiformes,Prostigmata,Anystina,Parasitengona,Trombidioidea,Trombidiidae,Dinothrombium.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Annelida,Clitellata,Hirudinea,Rhynchobdellida,Glossiphoniidae,Helobdella.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Hymenoptera,Apocrita,Parasitoida,Chalcidoidea,Trichogrammatidae,Trichogramma.
# Eukaryota,Metazoa,Echinodermata,Eleutherozoa,Echinozoa,Holothuroidea,Aspidochirotacea,Aspidochirotida,Stichopodidae,Apostichopus.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Diptera,Nematocera,Chironomoidea,Chironomidae,Clunio.
# Eukaryota,Metazoa,Placozoa,Trichoplacidae,Trichoplax.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Chelicerata,Arachnida,Acari,Acariformes,Sarcoptiformes,Astigmata,Psoroptidia,Analgoidea,Pyroglyphidae,Dermatophagoidinae,Dermatophagoides.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Paraneoptera,Hemiptera,Sternorrhyncha,Aphidomorpha,Aphidoidea,Aphididae,Macrosiphini,Acyrthosiphon.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Endopterygota,Coleoptera,Polyphaga,Elateriformia,Buprestoidea,Buprestidae,Agrilinae,Agrilus.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Chelicerata,Arachnida,Acari,Parasitiformes,Ixodida,Ixodoidea,Ixodidae,Ixodinae,Ixodes.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Hexapoda,Insecta,Pterygota,Neoptera,Paraneoptera,Hemiptera,Sternorrhyncha,Psylloidea,Liviidae,Diaphorina.
# Eukaryota,Metazoa,Porifera,Demospongiae,Heteroscleromorpha,Haplosclerida,Niphatidae,Amphimedon.
# Eukaryota,Metazoa,Ecdysozoa,Arthropoda,Crustacea,Multicrustacea,Hexanauplia,Cirripedia,Thoracica,Sessilia,Balanidae,Amphibalanus.
# Eukaryota,Metazoa,Cnidaria,Anthozoa,Hexacorallia,Actiniaria,Actiniidae,Actinia.
# Eukaryota,Rhodophyta,Bangiophyceae,Cyanidiales,Cyanidiaceae,Galdieria.
# Eukaryota,Sar,Alveolata,Colpodellida,Vitrellaceae,Vitrella.
# Eukaryota,Amoebozoa,Evosea,Eumycetozoa,Dictyostelia,Dictyosteliales,Dictyosteliaceae,Dictyostelium.
# Eukaryota,Sar,Alveolata,Colpodellida,Vitrellaceae,Vitrella.
# Eukaryota,Sar,Stramenopiles,Ochrophyta,PX clade,Phaeophyceae,Ectocarpales,Ectocarpaceae,Ectocarpus.
# Eukaryota,Metazoa,Spiralia,Lophotrochozoa,Mollusca,Cephalopoda,Coleoidea,Octopodiformes,Octopoda,Incirrata,Octopodidae,Octopus.
# Eukaryota,Amoebozoa,Evosea,Variosea,Cavosteliida,Cavosteliaceae,Planoprotostelium.
# Bacteria,Firmicutes,Clostridia,Thermoanaerobacterales,Zhaonellaceae,Zhaonella.
# Eukaryota,Amoebozoa,Evosea,Variosea,Cavosteliida,Cavosteliaceae,Planoprotostelium.
# Eukaryota,Metazoa,Cnidaria,Anthozoa,Hexacorallia,Actiniaria,Edwardsiidae,Nematostella.
# Bacteria.
# Eukaryota,Sar,Stramenopiles,Bigyra,Labyrinthulomycetes,Thraustochytrida,Thraustochytriaceae,Hondaea.
# Eukaryota,Cryptophyceae,Pyrenomonadales,Geminigeraceae,Guillardia.
# Bacteria,Planctomycetes,Phycisphaerae,Sedimentisphaerales,Anaerohalosphaeraceae,Anaerohalosphaera.
# Archaea,Candidatus Thermoplasmatota,Thermoplasmata,Thermoplasmatales.
# Bacteria.
# Bacteria,Candidatus Kryptonia,Candidatus Kryptonium.
# Bacteria,Candidatus Marinimicrobia.
# Bacteria.
# Bacteria,Kiritimatiellaeota,Kiritimatiellae,Kiritimatiellales,Kiritimatiellaceae,Kiritimatiella.
# Bacteria,Proteobacteria,Deltaproteobacteria,Desulfovibrionales,Desulfovibrionaceae,Lawsonia.
# Bacteria,Thermotogae,Thermotogales,Thermotogaceae,Thermotoga.
# Bacteria,Proteobacteria,Deltaproteobacteria,Desulfovibrionales,Desulfovibrionaceae,Lawsonia.
# Bacteria,Proteobacteria,Deltaproteobacteria,Desulfobacterales,Desulfobacteraceae,Desulfatibacillum.
# Archaea.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Aureibacillus.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Caldalkalibacillus.
# Bacteria.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Oscillospiraceae,Sporobacter.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales,Nannocystineae,Kofleriaceae,Haliangium.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Caldibacillus.
# Bacteria,Firmicutes,Clostridia,Halanaerobiales,Halanaerobiaceae,Halothermothrix.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales,Cystobacterineae,Myxococcaceae,Corallococcus.
# Bacteria,Actinobacteria,Rubrobacteria,Rubrobacterales,Rubrobacteraceae,Rubrobacter.
# Bacteria,Firmicutes,Clostridia,Natranaerobiales,Natranaerobiaceae,Natranaerobius.
# Bacteria,Proteobacteria,Deltaproteobacteria,Desulfobacterales,Desulfobulbaceae,Desulfotalea.
# Bacteria,Proteobacteria,Gammaproteobacteria,Chromatiales,Wenzhouxiangellaceae,Wenzhouxiangella.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillales Family XII. Incertae Sedis,Exiguobacterium,unclassified Exiguobacterium.
# Bacteria,Actinobacteria,Thermoleophilia,Thermoleophilales,Thermoleophilaceae,Thermoleophilum.
# Bacteria,Firmicutes,Bacilli,Bacillales,Acidibacillus.
# Bacteria,Chloroflexi,Thermobaculum.
# Bacteria,Proteobacteria,Deltaproteobacteria,Bradymonadales,Bradymonadaceae,Bradymonas.
# Bacteria,Proteobacteria,Oligoflexia,Bacteriovoracales,Halobacteriovoraceae,Halobacteriovorax.
# Bacteria.
# Bacteria,Proteobacteria,Deltaproteobacteria.
# Bacteria,Chloroflexi,Dehalococcoidia.
# Bacteria,Firmicutes,Bacilli,Bacillales,Alicyclobacillaceae,Alicyclobacillus.
# Bacteria,Chlamydiae,Parachlamydiales,Simkaniaceae,Simkania.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Peptococcaceae,Dehalobacter,unclassified Dehalobacter.
# Bacteria,Proteobacteria,Alphaproteobacteria,Rhodospirillales,Rhodospirillaceae,Telmatospirillum.
# Bacteria,Proteobacteria,Betaproteobacteria,Burkholderiales,Burkholderiaceae,Lautropia.
# Bacteria,Fibrobacteres,Chitinivibrionia,Chitinivibrionales,Chitinivibrionaceae,Chitinivibrio.
# Archaea,Crenarchaeota,Thermoprotei,Fervidicoccales,Fervidicoccaceae,Fervidicoccus.
# Bacteria,Actinobacteria,Streptosporangiales,Streptosporangiaceae,Thermobispora.
# Bacteria,Proteobacteria,Betaproteobacteria.
# Bacteria,Chlorobi,Chlorobia,Chlorobiales,Chlorobiaceae,Chlorobium/Pelodictyon group,Chlorobium.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Pueribacillus.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales,Saccharospirillaceae,Reinekea.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales.
# Bacteria.
# Bacteria,Spirochaetes,Spirochaetales,Spirochaetaceae,Alkalispirochaeta.
# Eukaryota,Metazoa,Ecdysozoa,Tardigrada,Eutardigrada,Parachela,Hypsibioidea,Ramazzottiidae,Ramazzottius.
# Archaea,Crenarchaeota,Thermoprotei,Acidilobales,Caldisphaeraceae,Caldisphaera.
# Bacteria,Planctomycetes.
# Bacteria,Proteobacteria,Gammaproteobacteria.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Lysinibacillus,unclassified Lysinibacillus.
# Bacteria,Nitrospinae/Tectomicrobia group,Candidatus Tectomicrobia,Candidatus Entotheonella.
# Bacteria,Firmicutes,Bacilli,Bacillales,Thermoactinomycetaceae,Novibacillus.
# Bacteria,Proteobacteria,Alphaproteobacteria,Rhizobiales,Hyphomicrobiaceae,Blastochloris.
# Bacteria,Chloroflexi,Anaerolineae,Anaerolineales,Anaerolineaceae,Thermanaerothrix.
# Bacteria,Chloroflexi,Chloroflexia,Chloroflexales,Chloroflexineae,Chloroflexaceae,Chloroflexus.
# Bacteria,Firmicutes,Bacilli,Bacillales,Staphylococcaceae,Staphylococcus.
# Bacteria.
# Bacteria,Proteobacteria,Gammaproteobacteria,Sedimenticola.
# Archaea,Candidatus Thermoplasmatota,Thermoplasmata,Methanomassiliicoccales,Methanomassiliicoccaceae,Candidatus Methanoplasma.
# Bacteria,Proteobacteria,Betaproteobacteria,Candidatus Accumulibacter,unclassified Candidatus Accumulibacter.
# Bacteria,Firmicutes,Bacilli,Bacillales,Alicyclobacillaceae,Effusibacillus.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Peptococcaceae,Desulfonispora.
# Bacteria,Chloroflexi,Caldilineae,Caldilineales,Caldilineaceae,Caldilinea.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Bacillus.
# Bacteria,Proteobacteria,Gammaproteobacteria,Thiotrichales,Thiotrichaceae,Thiomargarita.
# Bacteria,Actinobacteria,Acidimicrobiia,Acidimicrobiales,Microthrixaceae,Candidatus Microthrix.
# Bacteria,Chlamydiae,Chlamydiales.
# Archaea,Euryarchaeota,Stenosarchaea group,Halobacteria,Halobacteriales.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Bacillus.
# Bacteria,Actinobacteria,Actinopolysporales,Actinopolysporaceae,Actinopolyspora.
# Bacteria,Actinobacteria,Acidimicrobiia,Acidimicrobiales,Acidimicrobiaceae,Ferrithrix.
# Bacteria,Chloroflexi,Sphaerobacteridae,Sphaerobacterales,Sphaerobacterineae,Sphaerobacteraceae,Nitrolancea.
# Bacteria,Actinobacteria,Pseudonocardiales,Pseudonocardiaceae,Pseudonocardia,unclassified Pseudonocardia.
# Bacteria,Thermotogae,Kosmotogales,Kosmotogaceae,Kosmotoga.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales,Sorangiineae,Sandaracinaceae,Sandaracinus.
# Bacteria,Actinobacteria,Micrococcales,Kytococcaceae,Kytococcus,unclassified Kytococcus.
# Bacteria,Firmicutes,Limnochordia,Limnochordales,Limnochordaceae,Limnochorda.
# Bacteria,Proteobacteria,Gammaproteobacteria,Alteromonadales,Shewanellaceae,Shewanella.
# Bacteria,Proteobacteria,Gammaproteobacteria,Enterobacterales,Enterobacteriaceae,Escherichia.
# Bacteria,Actinobacteria.
# Bacteria,Actinobacteria,Geodermatophilales,Geodermatophilaceae,Blastococcus.
# Bacteria,Verrucomicrobia,Verrucomicrobiae,unclassified Verrucomicrobiae.
# Bacteria,Kiritimatiellaeota,unclassified Kiritimatiellaeota.
# Bacteria,Actinobacteria,Thermoleophilia,Solirubrobacterales,Solirubrobacteraceae,Solirubrobacter.
# Bacteria,Actinobacteria,Acidimicrobiia,Acidimicrobiales,Iamiaceae,Actinomarinicola.
# Bacteria,Actinobacteria,Micrococcales,Dermabacteraceae,Dermabacter,unclassified Dermabacter.
# Archaea,Crenarchaeota,Thermoprotei,Acidilobales,Caldisphaeraceae,Caldisphaera.
# Bacteria,Actinobacteria,Corynebacteriales,Nocardiaceae,Rhodococcus.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales,Sorangiineae,Polyangiaceae,Sorangium.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Symbiobacteriaceae,Symbiobacterium.
# Bacteria,Proteobacteria,Gammaproteobacteria,Chromatiales,Ectothiorhodospiraceae,Halorhodospira.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Paraliobacillus,unclassified Paraliobacillus.
# Bacteria.
# Bacteria,Proteobacteria,Gammaproteobacteria,Chromatiales,Ectothiorhodospiraceae,Thioalbus.
# Bacteria,Actinobacteria,Nakamurellales,Nakamurellaceae,Nakamurella,unclassified Nakamurella.
# Bacteria,Actinobacteria,Propionibacteriales,Nocardioidaceae,Thermasporomyces.
# Bacteria,Actinobacteria,Corynebacteriales,Mycobacteriaceae,Mycobacterium,Mycobacterium tuberculosis complex.
# Bacteria,Ignavibacteriae,Ignavibacteria,Ignavibacteriales,Melioribacteraceae,Melioribacter.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Paraliobacillus,unclassified Paraliobacillus.
# Bacteria,unclassified candidate division Zixibacteria.
# Bacteria,Actinobacteria,Streptosporangiales,Thermomonosporaceae,Actinomadura,unclassified Actinomadura.
# Bacteria,Proteobacteria,Deltaproteobacteria,Desulfobacterales,Desulfobacteraceae,Desulfatibacillum.
# Bacteria,Proteobacteria,Alphaproteobacteria,Rhodospirillales,Rhodospirillaceae,Magnetospirillum.
# Bacteria,Firmicutes,Bacilli,Bacillales,Staphylococcaceae,Nosocomiicoccus.
# Bacteria.
# Archaea,Euryarchaeota,Stenosarchaea group,Halobacteria,Halobacteriales,Halobacteriaceae,Halobacterium.
# Archaea,Crenarchaeota,Thermoprotei,Desulfurococcales,Desulfurococcaceae.
# Bacteria,Actinobacteria,Corynebacteriales,Corynebacteriaceae,Corynebacterium.
# Archaea,Candidatus Altiarchaeota,Candidatus Altiarchaeales.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales,Saccharospirillaceae,Gynuella.
# Bacteria,Firmicutes,Clostridia,Thermoanaerobacterales,Thermoanaerobacterales Family IV. Incertae Sedis,Mahella.
# Bacteria,Actinobacteria,Thermoleophilia,Solirubrobacterales,Conexibacteraceae,Conexibacter,unclassified Conexibacter.
# Bacteria,Actinobacteria,Micrococcales,Microbacteriaceae,Microbacterium.
# Bacteria,Actinobacteria,Propionibacteriales,Kribbellaceae,Kribbella.
# Bacteria,Chlamydiae,Parachlamydiales,Rhabdochlamydiaceae,Candidatus Rhabdochlamydia,unclassified Candidatus Rhabdochlamydia.
# Bacteria,Actinobacteria,Pseudonocardiales,Pseudonocardiaceae,Saccharopolyspora.
# Bacteria,Actinobacteria.
# Bacteria,Verrucomicrobia,Opitutae,Puniceicoccales.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Caldicoprobacteraceae,Caldicoprobacter.
# Bacteria,unclassified candidate division Zixibacteria.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales,Sorangiineae.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Gracilibacillus.
# Bacteria,Actinobacteria,Pseudonocardiales,Pseudonocardiaceae,Pseudonocardia.
# Bacteria,Proteobacteria,Deltaproteobacteria,Syntrophobacterales,Syntrophaceae,Desulfomonile.
# Bacteria,Actinobacteria,Streptosporangiales.
# Bacteria,Proteobacteria,Deltaproteobacteria,Desulfobacterales,Desulfobulbaceae,Desulfobulbus.
# Bacteria,Candidatus Margulisbacteria,Candidatus Marinamargulisbacteria.
# Bacteria,Proteobacteria,Deltaproteobacteria,Syntrophobacterales,Syntrophaceae,Syntrophus.
# Eukaryota,Amoebozoa,Evosea,Eumycetozoa,Dictyostelia,Dictyosteliales,Dictyosteliaceae,Dictyostelium.
# Bacteria,Actinobacteria,Micrococcales,Microbacteriaceae,Microbacterium.
# Bacteria,Proteobacteria,Oligoflexia,Silvanigrellales,Silvanigrellaceae,Silvanigrella.
# Bacteria,Actinobacteria,Corynebacteriales,Segniliparaceae,Segniliparus.
# Bacteria,Spirochaetes,Spirochaetales,Spirochaetaceae,Spirochaeta.
# Bacteria,Proteobacteria,Gammaproteobacteria,Thiotrichales,unclassified Thiotrichales.
# Bacteria,Firmicutes,Bacilli,Bacillales,Sporolactobacillaceae,Sporolactobacillus,unclassified Sporolactobacillus.
# Bacteria,Proteobacteria,Gammaproteobacteria,Thiotrichales,Thiotrichaceae,Thiothrix.
# Bacteria,Verrucomicrobia,Verrucomicrobiae,Verrucomicrobiales.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Rikenellaceae,Alistipes.
# Bacteria,Actinobacteria,Acidimicrobiia,Acidimicrobiales,Acidimicrobiaceae,Acidimicrobium.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Bacteroidaceae,Bacteroides,environmental samples.
# Bacteria,Firmicutes,Bacilli,Bacillales,Listeriaceae,Listeria.
# Eukaryota,Sar,Stramenopiles,Ochrophyta,Pelagophyceae,Pelagomonadales,Aureococcus.
# Bacteria,Actinobacteria,Micrococcales,Microbacteriaceae,Amnibacterium.
# Bacteria,Chloroflexi,Ktedonobacteria,Thermogemmatisporales,Thermogemmatisporaceae,Thermogemmatispora.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiales Family XVII. Incertae Sedis,Sulfobacillus.
# Bacteria,Actinobacteria,Acidimicrobiia,Acidimicrobiales,Acidimicrobiaceae,Acidithrix.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Porphyromonadaceae,unclassified Porphyromonadaceae.
# Bacteria,Actinobacteria,Acidimicrobiia.
# Bacteria,Actinobacteria,Micrococcales,Microbacteriaceae,Agrococcus.
# Bacteria,Actinobacteria,Propionibacteriales,Propionibacteriaceae.
# Bacteria,Actinobacteria,Kineosporiales,Kineosporiaceae,Quadrisphaera,unclassified Quadrisphaera.
# Bacteria,Bacteroidetes,Flavobacteriia,Flavobacteriales,Luteibaculaceae,Luteibaculum.
# Bacteria,Candidatus Marinimicrobia.
# Bacteria,Actinobacteria,Micrococcales,Rarobacteraceae,Rarobacter.
# Bacteria,Actinobacteria,Streptosporangiales,Treboniaceae,Trebonia.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Prevotellaceae,Alloprevotella.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiaceae,Thermotalea.
# Bacteria,Firmicutes,Tissierellia,Tissierellales,Peptoniphilaceae,Anaerococcus.
# Bacteria,Chloroflexi,SAR202 cluster.
# Bacteria,Actinobacteria,Micrococcales,Microbacteriaceae,Amnibacterium.
# Bacteria,Balneolaeota,unclassified Balneolaeota,Candidatus Cyclonatronum.
# Bacteria,Actinobacteria,Micrococcales,Microbacteriaceae,Pseudoclavibacter.
# Bacteria,Actinobacteria,Propionibacteriales,Propionibacteriaceae,Propionimicrobium.
# Bacteria,Verrucomicrobia,Opitutae,Puniceicoccales,Puniceicoccaceae,Coraliomargarita.
# Bacteria,Bacteroidetes,Flavobacteriia,Flavobacteriales,Crocinitomicaceae,Putridiphycobacter.
# Bacteria,Proteobacteria,Alphaproteobacteria,Rhizobiales,Rhodobiaceae,Afifella.
# Bacteria,Actinobacteria,Micrococcales,Ruaniaceae.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Peptococcaceae,Peptococcus.
# Bacteria,Cyanobacteria,Gloeobacteria,Gloeobacterales,Gloeobacteraceae,Gloeobacter.
# Bacteria,Proteobacteria,Gammaproteobacteria,Pasteurellales,Pasteurellaceae,Haemophilus.
# Bacteria,Proteobacteria,Alphaproteobacteria,Rhodospirillales,Rhodospirillaceae,Magnetospira,unclassified Magnetospira.
# Bacteria,Chlamydiae,Parachlamydiales,Parachlamydiaceae,Candidatus Protochlamydia.
# Bacteria,unclassified candidate division Zixibacteria.
# Bacteria,Proteobacteria,Gammaproteobacteria,Cardiobacteriales,Cardiobacteriaceae,Dichelobacter.
# Bacteria,Chloroflexi,Ktedonobacteria,Thermogemmatisporales,Thermogemmatisporaceae,Thermogemmatispora.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiales Family XII. Incertae Sedis,Fusibacter,unclassified Fusibacter.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiales Family XVII. Incertae Sedis,Thermaerobacter.
# Bacteria,Firmicutes,Bacilli,Bacillales,Bacillaceae,Marinococcus.
# Bacteria,Actinobacteria,Streptosporangiales,Nocardiopsaceae,Streptomonospora,unclassified Streptomonospora.
# Archaea,Crenarchaeota,Thermoprotei,Thermoproteales,Thermoproteaceae,Caldivirga.
# Bacteria,Actinobacteria,Kineosporiales,Kineosporiaceae,unclassified Angustibacter.
# Bacteria,Actinobacteria,Corynebacteriales,Lawsonellaceae,Lawsonella.
# Bacteria,Actinobacteria,Micrococcales,Ornithinimicrobiaceae,Serinicoccus.
# Bacteria,Actinobacteria,Micrococcales,Demequinaceae,Demequina.
# Bacteria,Actinobacteria,Micrococcales,Microbacteriaceae,Curtobacterium.
# Bacteria,Bacteroidetes,Bacteroidia,Marinilabiliales,Prolixibacteraceae,Mangrovibacterium.
# Bacteria,Bacteroidetes,Flavobacteriia,Flavobacteriales,Flavobacteriaceae.
# Bacteria,Proteobacteria,Gammaproteobacteria,Chromatiales,Chromatiaceae,Allochromatium.
# Bacteria,Actinobacteria,Candidatus Nanopelagicales,Candidatus Nanopelagicaceae,Candidatus Nanopelagicus.
# Archaea,Crenarchaeota,Thermoprotei,Thermoproteales,Thermofilaceae,Thermofilum.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales,Oceanospirillaceae,unclassified Oceanospirillaceae.
# Bacteria,Actinobacteria,Micrococcales,Microbacteriaceae,Gulosibacter,unclassified Gulosibacter.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales,Sorangiineae,Polyangiaceae.
# Bacteria,Actinobacteria,Pseudonocardiales,Pseudonocardiaceae.
# Bacteria,Actinobacteria,Micrococcales,Tropherymataceae,Tropheryma.
# Bacteria,Actinobacteria,Kineosporiales,Kineosporiaceae,Pseudokineococcus.
# Bacteria,Rhodothermaeota,Rhodothermia,Rhodothermales,Rubricoccaceae,Rubricoccus.
# Bacteria,Actinobacteria,Corynebacteriales,Gordoniaceae,Gordonia.
# Archaea,Thaumarchaeota,Conexivisphaeria,Conexivisphaerales,Conexivisphaeraceae,Conexivisphaera.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Flammeovirgaceae,Flammeovirga.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Peptostreptococcaceae.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Porphyromonadaceae,Porphyromonas,unclassified Porphyromonas.
# Bacteria,Actinobacteria,Motilibacterales,Motilibacteraceae,Motilibacter.
# Bacteria,Actinobacteria,Kineosporiales,Kineosporiaceae,Kineococcus.
# Bacteria,Proteobacteria,Gammaproteobacteria,Thiotrichales,Thiotrichaceae,Beggiatoa.
# Bacteria,Proteobacteria,Deltaproteobacteria,Desulfobacterales,Desulfobacteraceae,Desulfobotulus.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Fulvivirgaceae,Fulvivirga.
# Bacteria,Proteobacteria.
# Bacteria,Proteobacteria,Gammaproteobacteria,Celerinatantimonadaceae,Celerinatantimonas.
# Bacteria,Proteobacteria,Betaproteobacteria,Burkholderiales,Piscinibacter.
# Archaea.
# Bacteria,Bacteroidetes,Flavobacteriia,Flavobacteriales,Weeksellaceae,Apibacter.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Cyclobacteriaceae,Algoriphagus.
# Bacteria,Bacteroidetes,Flavobacteriia,Flavobacteriales,Weeksellaceae,Ornithobacterium.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiaceae,Butyricicoccus,unclassified Butyricicoccus.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales.
# Bacteria,Actinobacteria,Actinomycetales.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Cytophagaceae,Cytophaga.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales,Cystobacterineae,Myxococcaceae,Corallococcus.
# Bacteria,Proteobacteria,Gammaproteobacteria,Vibrionales,Vibrionaceae,Enterovibrio.
# Bacteria,Actinobacteria,Propionibacteriales,Nocardioidaceae,Aeromicrobium.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales,Aestuariirhabdaceae,Aestuariirhabdus.
# Bacteria,Proteobacteria.
# Bacteria,Actinobacteria,Micrococcales,Micrococcaceae,Neomicrococcus.
# Bacteria,Cyanobacteria,Synechococcales,Acaryochloridaceae,Acaryochloris.
# Bacteria,Proteobacteria,Deltaproteobacteria,Syntrophobacterales,Syntrophaceae,Syntrophus.
# Bacteria,Actinobacteria,Micrococcales,Beutenbergiaceae,Miniimonas.
# Bacteria,Candidatus Margulisbacteria,Candidatus Marinamargulisbacteria.
# Bacteria,Actinobacteria,Coriobacteriia,Eggerthellales,Eggerthellaceae.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales,Oceanospirillaceae,Nitrincola.
# Bacteria,Actinobacteria,Micrococcales,Dermacoccaceae,Flexivirga.
# Bacteria,Cyanobacteria,Synechococcales,Synechococcaceae,Synechococcus,unclassified Synechococcus.
# Bacteria,Proteobacteria,Alphaproteobacteria,Rhodospirillales,Rhodospirillaceae,Rhodospirillum.
# Bacteria,Firmicutes,Clostridia,Halanaerobiales,Halanaerobiaceae,Halanaerobium.
# Bacteria,Chloroflexi,Thermoflexia,Thermoflexales,Thermoflexaceae,Thermoflexus.
# Bacteria,Actinobacteria,Actinomycetales,Actinomycetaceae,Flaviflexus.
# Bacteria,Actinobacteria.
# Bacteria,Actinobacteria,Jiangellales,Jiangellaceae,Phytoactinopolyspora.
# Bacteria,Actinobacteria,Micrococcales,Dermacoccaceae,Dermacoccus.
# Bacteria,Firmicutes,Clostridia,Halanaerobiales,Anoxybacter.
# Bacteria,Proteobacteria,Betaproteobacteria,Burkholderiales,Sutterellaceae,Sutterella.
# Bacteria,Chloroflexi,Thermoflexia,Thermoflexales,Thermoflexaceae,Thermoflexus.
# Bacteria,Actinobacteria,Nitriliruptoria,Egibacterales,Egibacteraceae,Egibacter.
# Bacteria,Bacteroidetes,Bacteroidia,Marinilabiliales,Marinifilaceae,Ancylomarina.
# Bacteria,Proteobacteria,Gammaproteobacteria,Chromatiales,Ectothiorhodospiraceae,Thiorhodospira.
# Eukaryota,Viridiplantae,Chlorophyta,Mamiellophyceae,Mamiellales,Mamiellaceae,Micromonas.
# Bacteria,Actinobacteria,Nitriliruptoria,Euzebyales,unclassified Euzebya.
# Bacteria,Proteobacteria,Deltaproteobacteria,Myxococcales,Nannocystineae,Nannocystaceae,Nannocystis.
# Bacteria,Proteobacteria,Oligoflexia,Bdellovibrionales,Bdellovibrionaceae,Bdellovibrio.
# Bacteria,Actinobacteria,Propionibacteriales,Propionibacteriaceae,Microlunatus.
# Bacteria,Firmicutes,Clostridia,Thermoanaerobacterales,Thermoanaerobacteraceae,Caldanaerobacter.
# Bacteria,Fusobacteria,Fusobacteriales,Fusobacteriaceae,Fusobacterium.
# Bacteria.
# Bacteria,Cyanobacteria,Synechococcales,Merismopediaceae,Synechocystis,unclassified Synechocystis.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiaceae,Caloramator.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Oscillospiraceae,Sporobacter.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales,Oceanospirillaceae,Pseudospirillum.
# Bacteria,Actinobacteria,Micrococcales,Cellulomonadaceae,Cellulomonas.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiaceae,Sarcina,unclassified Sarcina.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Flexibacteraceae,Flexibacter.
# Bacteria,Proteobacteria,Gammaproteobacteria,sulfur-oxidizing symbionts.
# Bacteria,Actinobacteria,Coriobacteriia,Coriobacteriales,unclassified Coriobacteriales.
# Bacteria,Firmicutes,Bacilli,Bacillales,Alicyclobacillaceae,Kyrpidia.
# Bacteria,Proteobacteria,Gammaproteobacteria,Orbales,Orbaceae,Orbus.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Raineyaceae,Raineya.
# Bacteria,Actinobacteria,Micrococcales,Intrasporangiaceae,Phycicoccus.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Porphyromonadaceae,Porphyromonas,unclassified Porphyromonas.
# Bacteria,Proteobacteria,Oligoflexia,Oligoflexales,Pseudobacteriovoracaceae,Pseudobacteriovorax.
# Bacteria,Proteobacteria,Gammaproteobacteria,Pseudomonadales,Moraxellaceae,Moraxella.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Cytophagaceae,Chryseotalea.
# Bacteria,Firmicutes,Hydrogenispora.
# Archaea,Crenarchaeota,Thermoprotei,Acidilobales,Caldisphaeraceae,Caldisphaera.
# Bacteria,Chloroflexi,Ktedonobacteria,Thermogemmatisporales,Thermogemmatisporaceae,Thermogemmatispora.
# Bacteria,Bacteroidetes.
# Bacteria,Actinobacteria,Propionibacteriales,Propionibacteriaceae,Tessaracoccus,unclassified Tessaracoccus.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales,Oceanospirillales incertae sedis,Pelagibaculum.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiaceae,Clostridium.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Salinivirgaceae,Salinivirga.
# Bacteria,Actinobacteria,Micrococcales,Dermatophilaceae,Dermatophilus.
# Bacteria,Proteobacteria,Gammaproteobacteria.
# Bacteria,Spirochaetes,Spirochaetales,Spirochaetaceae,Treponema.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Cesiribacteraceae,Cesiribacter.
# Bacteria,Bacteroidetes,Flavobacteriia,Flavobacteriales,Schleiferiaceae,Schleiferia.
# Bacteria,Proteobacteria,Gammaproteobacteria,Chromatiales,Ectothiorhodospiraceae,Ectothiorhodosinus.
# Bacteria,Actinobacteria,Micrococcales,Micrococcaceae,Micrococcus.
# Bacteria,Bacteroidetes,Flavobacteriia,Flavobacteriales,Flavobacteriaceae,Capnocytophaga.
# Bacteria,Actinobacteria,Micrococcales,Bogoriellaceae,Bogoriella.
# Eukaryota,Apusozoa,Apusomonadidae,Thecamonas.
# Bacteria,Lentisphaerae,Lentisphaeria,Lentisphaerales,Lentisphaeraceae,Lentisphaera.
# Bacteria,Proteobacteria,Betaproteobacteria,Burkholderiales.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Syntrophomonadaceae,Dethiobacter.
# Bacteria,Actinobacteria,Actinomycetales,Actinomycetaceae,Actinomyces.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Cytophagaceae,Aquirufa.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Paludibacteraceae,Paludibacter.
# Bacteria,Proteobacteria,Deltaproteobacteria,Syntrophobacterales,Syntrophaceae,Desulfobacca.
# Bacteria,Actinobacteria,Propionibacteriales,Propionibacteriaceae,Raineyella.
# Bacteria,Bacteroidetes,Flavobacteriia.
# Bacteria,Actinobacteria,Actinomycetales,Actinomycetaceae,Bowdeniella.
# Bacteria,Actinobacteria,Acidimicrobiia,Acidimicrobiales,Ilumatobacteraceae,Ilumatobacter.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Syntrophomonadaceae,Dethiobacter.
# Archaea,Candidatus Thermoplasmatota,Thermoplasmata,Methanomassiliicoccales,Methanomassiliicoccaceae,Methanomassiliicoccus.
# Bacteria,Actinobacteria,Actinomycetales,Actinomycetaceae,Varibaculum.
# Bacteria,Actinobacteria,Propionibacteriales,Propionibacteriaceae,Propioniferax.
# Bacteria,Verrucomicrobia,Verrucomicrobiae,Verrucomicrobiales,Akkermansiaceae,Akkermansia.
# Eukaryota,Amoebozoa,Evosea,Eumycetozoa,Dictyostelia,Dictyosteliales,Dictyosteliaceae,Dictyostelium.
# Bacteria,Bacteroidetes,Flavobacteriia,Flavobacteriales,Salibacteraceae,Salibacter.
# Archaea,Thaumarchaeota,Nitrosopumilales,Nitrosopumilaceae,Nitrosopumilus.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Lentimicrobiaceae,Lentimicrobium.
# Bacteria,Actinobacteria,Micrococcales,Promicromonosporaceae,Isoptericola.
# Bacteria,Firmicutes,Clostridia,Thermoanaerobacterales,Thermoanaerobacterales Family IV. Incertae Sedis,Mahella.
# Bacteria,Firmicutes,Clostridia,Eubacteriales,Clostridiaceae,Caloramator.
# Bacteria,Proteobacteria,Gammaproteobacteria,Chromatiales,Wenzhouxiangellaceae,Wenzhouxiangella.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Rikenellaceae,Acetobacteroides.
# Eukaryota,Sar,Stramenopiles,Ochrophyta,Bacillariophyta,Bacillariophyceae,Bacillariophycidae,Naviculales,Naviculaceae,Fistulifera.
# Eukaryota,Sar,Stramenopiles,Ochrophyta,Bacillariophyta,Bacillariophyceae,Bacillariophycidae,Naviculales,Naviculaceae,Fistulifera.
# Bacteria,Proteobacteria,Gammaproteobacteria,Oceanospirillales,Oceanospirillaceae,Bermanella.
# Bacteria,Spirochaetes,Spirochaetales,Spirochaetaceae,Alkalispirochaeta.
# Bacteria,Actinobacteria,Micrococcales,Cellulomonadaceae,Pseudactinotalea,unclassified Pseudactinotalea.
# Bacteria,Proteobacteria,Deltaproteobacteria,Syntrophobacterales,Syntrophaceae,Desulfomonile.
# Eukaryota,Viridiplantae,Chlorophyta,Chloropicophyceae,Chloropicales,Chloropicaceae,Chloropicon.
# Bacteria,Proteobacteria,Gammaproteobacteria,Thiotrichales,Piscirickettsiaceae,Sulfurivirga.
# Bacteria,Chloroflexi,Caldilineae,Caldilineales,Caldilineaceae,Caldilinea.
# Bacteria,Proteobacteria,Gammaproteobacteria,Thiohalorhabdus.
# Eukaryota,Viridiplantae,Chlorophyta,core chlorophytes,Trebouxiophyceae,Trebouxiophyceae incertae sedis,Elliptochloris clade,Coccomyxa.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,eudicotyledons,Gunneridae,Pentapetalae,rosids,fabids,Fabales,Fabaceae,Papilionoideae,50 kb inversion clade,NPAAA clade,indigoferoid/millettioid clade,Phaseoleae,Glycine,Glycine subgen. Soja.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Bryophyta,Bryophytina,Bryopsida,Funariidae,Funariales,Funariaceae,Physcomitrium.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Bryophyta,Bryophytina,Bryopsida,Funariidae,Funariales,Funariaceae,Physcomitrium.
# Bacteria,Firmicutes,Negativicutes,Veillonellales,Veillonellaceae,Veillonella.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,Ranunculales,Ranunculaceae,Thalictroideae,Aquilegia.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,eudicotyledons,Gunneridae,Pentapetalae,rosids,fabids,Fabales,Fabaceae,Papilionoideae,50 kb inversion clade,NPAAA clade,indigoferoid/millettioid clade,Phaseoleae,Glycine,Glycine subgen. Soja.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Bryophyta,Bryophytina,Bryopsida,Funariidae,Funariales,Funariaceae,Physcomitrium.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Amoebophilaceae,Candidatus Amoebophilus.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Bernardetiaceae,Bernardetia.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,eudicotyledons,Gunneridae,Pentapetalae,asterids,lamiids,Solanales,Convolvulaceae,Cuscuteae,Cuscuta,Cuscuta subgen. Grammica,Cuscuta sect. Cleistogrammica.
# Bacteria,Proteobacteria,Gammaproteobacteria,Cellvibrionales,Porticoccaceae,SAR92 clade.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,eudicotyledons,Gunneridae,Pentapetalae,rosids,fabids,Fabales,Fabaceae,Papilionoideae,50 kb inversion clade,NPAAA clade,indigoferoid/millettioid clade,Phaseoleae,Glycine,Glycine subgen. Soja.
# Archaea,Euryarchaeota,candidate division MSBL1.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,eudicotyledons,Gunneridae,Pentapetalae,rosids,fabids,Fabales,Fabaceae,Papilionoideae,50 kb inversion clade,NPAAA clade,Hologalegina,IRL clade,Trifolieae,Trifolium.
# Bacteria,Chloroflexi,Dehalococcoidia,Dehalococcoidales,Dehalococcoidaceae,Dehalococcoides.
# Bacteria,Proteobacteria,Deltaproteobacteria,Syntrophobacterales,Syntrophaceae,Smithella,unclassified Smithella.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Marchantiophyta,Marchantiopsida,Marchantiidae,Marchantiales,Marchantiaceae,Marchantia.
# Bacteria,Actinobacteria,Streptomycetales,Streptomycetaceae,Embleya.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,eudicotyledons,Gunneridae,Pentapetalae,asterids,campanulids,Asterales,Asteraceae,Cichorioideae,Cichorieae,Lactucinae,Lactuca.
# Archaea,Euryarchaeota,Stenosarchaea group,Methanomicrobia,Methanosarcinales,Methanotrichaceae,Methanothrix.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,eudicotyledons,Gunneridae,Pentapetalae,asterids,Ericales,Actinidiaceae,Actinidia.
# Bacteria,Bacteroidetes,Cytophagia,Cytophagales,Cytophagaceae,Fibrella.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,Liliopsida,Zosteraceae,Zostera.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,eudicotyledons,Gunneridae,Pentapetalae,asterids,lamiids,Lamiales,Gesneriaceae,Didymocarpoideae,Trichosporeae,Loxocarpinae,Dorcoceras.
# Bacteria,Actinobacteria,Pseudonocardiales,Pseudonocardiaceae,Pseudonocardia,unclassified Pseudonocardia.
# Bacteria,Proteobacteria,Alphaproteobacteria,Rhodothalassiales,Rhodothalassiaceae,Rhodothalassium.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,Liliopsida,Arecaceae,Arecoideae,Cocoseae,Elaeidinae,Elaeis.
# Eukaryota,Viridiplantae,Streptophyta,Embryophyta,Tracheophyta,Spermatophyta,Magnoliopsida,Liliopsida,Zingiberales,Musaceae,Musa.
# Bacteria,Proteobacteria,Gammaproteobacteria,Chromatiales,Ectothiorhodospiraceae,Thiohalospira.
# Archaea,Euryarchaeota,candidate division MSBL1.
# Bacteria,Proteobacteria,Deltaproteobacteria,Syntrophobacterales,Syntrophaceae,Syntrophus.
# Bacteria,Bacteroidetes,Bacteroidia,Bacteroidales,Salinivirgaceae,Salinivirga.
# Bacteria,Proteobacteria,Gammaproteobacteria,sulfur-oxidizing symbionts.
# Archaea,Euryarchaeota,Stenosarchaea group,Methanomicrobia,Methanomicrobiales,Methanocorpusculaceae,Methanocorpusculum.

# %%
# Most frequent taxonomic groups:
atleast = 1
for level in range(4):
    descr_list = [a.taxo.split(',')[level] for a in annot.values() \
                if len(a.taxo.split(',')) > level]
    descr_dict = {k:descr_list.count(k) for k in descr_list \
                if descr_list.count(k)>=atleast}
    print('\n Level %i:' % level)
    print(descr_dict)
# Out:
#  Level 0:
# {'': 1, 'Eukaryota': 91, 'Bacteria': 318, 'Archaea': 21}
#
#  Level 1:
# {'Metazoa': 57, 'Rhodophyta': 1, 'Sar': 7, 'Amoebozoa': 5, 'Firmicutes': 52, 'Cryptophyceae': 1, 'Planctomycetes': 2, 'Candidatus Thermoplasmatota': 3, 'Candidatus Kryptonia': 1, 'Candidatus Marinimicrobia': 2, 'Kiritimatiellaeota': 2, 'Proteobacteria': 81, 'Thermotogae': 2, 'Bacteroidetes': 37, 'Actinobacteria': 85, 'Chloroflexi': 14, 'Chlamydiae': 4, 'Fibrobacteres': 1, 'Crenarchaeota': 7, 'Chlorobi': 1, 'Spirochaetes': 4, 'Nitrospinae/Tectomicrobia group': 1, 'Euryarchaeota': 6, 'Verrucomicrobia': 5, 'Ignavibacteriae': 1, 'unclassified candidate division Zixibacteria': 3, 'Candidatus Altiarchaeota': 1, 'Candidatus Margulisbacteria': 2, 'Balneolaeota': 1, 'Cyanobacteria': 4, 'Rhodothermaeota': 1, 'Thaumarchaeota': 2, 'Viridiplantae': 19, 'Fusobacteria': 1, 'Apusozoa': 1, 'Lentisphaerae': 1}
#
#  Level 2:
# {'Chordata': 11, 'Echinodermata': 2, 'Cnidaria': 4, 'Ecdysozoa': 27, 'Spiralia': 11, 'Placozoa': 1, 'Porifera': 1, 'Bangiophyceae': 1, 'Alveolata': 2, 'Evosea': 5, 'Stramenopiles': 5, 'Clostridia': 27, 'Pyrenomonadales': 1, 'Phycisphaerae': 1, 'Thermoplasmata': 3, 'Candidatus Kryptonium': 1, 'Kiritimatiellae': 1, 'Deltaproteobacteria': 25, 'Thermotogales': 1, 'Bacilli': 21, 'Bacteroidia': 15, 'Rubrobacteria': 1, 'Gammaproteobacteria': 37, 'Thermoleophilia': 3, 'Thermobaculum': 1, 'Oligoflexia': 4, 'Dehalococcoidia': 2, 'Parachlamydiales': 3, 'Alphaproteobacteria': 7, 'Betaproteobacteria': 6, 'Chitinivibrionia': 1, 'Thermoprotei': 7, 'Streptosporangiales': 5, 'Chlorobia': 1, 'Spirochaetales': 4, 'Candidatus Tectomicrobia': 1, 'Anaerolineae': 1, 'Chloroflexia': 1, 'Caldilineae': 2, 'Acidimicrobiia': 7, 'Chlamydiales': 1, 'Stenosarchaea group': 4, 'Actinopolysporales': 1, 'Sphaerobacteridae': 1, 'Pseudonocardiales': 5, 'Kosmotogales': 1, 'Micrococcales': 26, 'Limnochordia': 1, 'Geodermatophilales': 1, 'Verrucomicrobiae': 3, 'unclassified Kiritimatiellaeota': 1, 'Corynebacteriales': 6, 'Nakamurellales': 1, 'Propionibacteriales': 9, 'Ignavibacteria': 1, 'Candidatus Altiarchaeales': 1, 'Opitutae': 2, 'Candidatus Marinamargulisbacteria': 2, 'Ktedonobacteria': 3, 'Kineosporiales': 4, 'Flavobacteriia': 9, 'Tissierellia': 1, 'SAR202 cluster': 1, 'unclassified Balneolaeota': 1, 'Gloeobacteria': 1, 'Candidatus Nanopelagicales': 1, 'Rhodothermia': 1, 'Conexivisphaeria': 1, 'Cytophagia': 12, 'Motilibacterales': 1, 'Actinomycetales': 5, 'Synechococcales': 3, 'Coriobacteriia': 2, 'Thermoflexia': 2, 'Jiangellales': 1, 'Nitriliruptoria': 2, 'Chlorophyta': 3, 'Fusobacteriales': 1, 'Hydrogenispora': 1, 'Apusomonadidae': 1, 'Lentisphaeria': 1, 'Nitrosopumilales': 1, 'Streptophyta': 16, 'Negativicutes': 1, 'candidate division MSBL1': 2, 'Streptomycetales': 1}
#
#  Level 3:
# {'Craniata': 10, 'Cephalochordata': 1, 'Eleutherozoa': 2, 'Anthozoa': 4, 'Arthropoda': 26, 'Lophotrochozoa': 11, 'Trichoplacidae': 1, 'Demospongiae': 1, 'Cyanidiales': 1, 'Colpodellida': 2, 'Eumycetozoa': 3, 'Ochrophyta': 4, 'Variosea': 2, 'Thermoanaerobacterales': 4, 'Bigyra': 1, 'Geminigeraceae': 1, 'Sedimentisphaerales': 1, 'Thermoplasmatales': 1, 'Kiritimatiellales': 1, 'Desulfovibrionales': 2, 'Thermotogaceae': 1, 'Desulfobacterales': 5, 'Myxococcales': 9, 'Bacillales': 21, 'Eubacteriales': 19, 'Halanaerobiales': 3, 'Bacteroidales': 13, 'Rubrobacterales': 1, 'Natranaerobiales': 1, 'Chromatiales': 8, 'Thermoleophilales': 1, 'Bradymonadales': 1, 'Bacteriovoracales': 1, 'Simkaniaceae': 1, 'Rhodospirillales': 4, 'Burkholderiales': 4, 'Chitinivibrionales': 1, 'Fervidicoccales': 1, 'Streptosporangiaceae': 1, 'Chlorobiales': 1, 'Oceanospirillales': 9, 'Spirochaetaceae': 4, 'Tardigrada': 1, 'Acidilobales': 3, 'Candidatus Entotheonella': 1, 'Rhizobiales': 2, 'Anaerolineales': 1, 'Chloroflexales': 1, 'Sedimenticola': 1, 'Methanomassiliicoccales': 2, 'Candidatus Accumulibacter': 1, 'Caldilineales': 2, 'Thiotrichales': 5, 'Acidimicrobiales': 6, 'Halobacteria': 2, 'Actinopolysporaceae': 1, 'Sphaerobacterales': 1, 'Pseudonocardiaceae': 5, 'Kosmotogaceae': 1, 'Kytococcaceae': 1, 'Limnochordales': 1, 'Alteromonadales': 1, 'Enterobacterales': 1, 'Geodermatophilaceae': 1, 'unclassified Verrucomicrobiae': 1, 'Solirubrobacterales': 2, 'Dermabacteraceae': 1, 'Nocardiaceae': 1, 'Nakamurellaceae': 1, 'Nocardioidaceae': 2, 'Mycobacteriaceae': 1, 'Ignavibacteriales': 1, 'Thermomonosporaceae': 1, 'Desulfurococcales': 1, 'Corynebacteriaceae': 1, 'Microbacteriaceae': 8, 'Kribbellaceae': 1, 'Rhabdochlamydiaceae': 1, 'Puniceicoccales': 2, 'Syntrophobacterales': 7, 'Silvanigrellales': 1, 'Segniliparaceae': 1, 'Verrucomicrobiales': 2, 'Thermogemmatisporales': 3, 'Propionibacteriaceae': 6, 'Kineosporiaceae': 4, 'Flavobacteriales': 8, 'Rarobacteraceae': 1, 'Treboniaceae': 1, 'Tissierellales': 1, 'Candidatus Cyclonatronum': 1, 'Ruaniaceae': 1, 'Gloeobacterales': 1, 'Pasteurellales': 1, 'Parachlamydiaceae': 1, 'Cardiobacteriales': 1, 'Nocardiopsaceae': 1, 'Thermoproteales': 2, 'Lawsonellaceae': 1, 'Ornithinimicrobiaceae': 1, 'Demequinaceae': 1, 'Marinilabiliales': 2, 'Candidatus Nanopelagicaceae': 1, 'Tropherymataceae': 1, 'Rhodothermales': 1, 'Gordoniaceae': 1, 'Conexivisphaerales': 1, 'Cytophagales': 12, 'Motilibacteraceae': 1, 'Celerinatantimonadaceae': 1, 'Vibrionales': 1, 'Micrococcaceae': 2, 'Acaryochloridaceae': 1, 'Beutenbergiaceae': 1, 'Eggerthellales': 1, 'Dermacoccaceae': 2, 'Synechococcaceae': 1, 'Thermoflexales': 2, 'Actinomycetaceae': 4, 'Jiangellaceae': 1, 'Egibacterales': 1, 'Mamiellophyceae': 1, 'Euzebyales': 1, 'Bdellovibrionales': 1, 'Fusobacteriaceae': 1, 'Merismopediaceae': 1, 'Cellulomonadaceae': 2, 'sulfur-oxidizing symbionts': 2, 'Coriobacteriales': 1, 'Orbales': 1, 'Intrasporangiaceae': 1, 'Oligoflexales': 1, 'Pseudomonadales': 1, 'Dermatophilaceae': 1, 'Bogoriellaceae': 1, 'Thecamonas': 1, 'Lentisphaerales': 1, 'Nitrosopumilaceae': 1, 'Promicromonosporaceae': 1, 'Chloropicophyceae': 1, 'Thiohalorhabdus': 1, 'core chlorophytes': 1, 'Embryophyta': 16, 'Veillonellales': 1, 'Cellvibrionales': 1, 'Dehalococcoidales': 1, 'Streptomycetaceae': 1, 'Methanomicrobia': 2, 'Rhodothalassiales': 1}

# %%
phylo = list();
fam_names = ['Eukaryota', 'Bacteria', 'Archaea']
col = (0, 0.8, 0.38)
#Eukaryota = red, Bacteria = purple, Archaea = green,

for i,k in enumerate(fam_names):
    sf = sca.Unit()
    sf.name = fam_names[i].lower()
    sf.col = col[i]
    sf.items = [j for j,q in enumerate(Dseq['hd'])  if sf.name in q.lower()]
    phylo.append(sf)

# %%
plt.rcParams['figure.figsize'] = 9, 8
U = Dsca['Uica'][1]
pairs = [[2*i,2*i+1] for i in range(floor(Dsect['kpos']/2))] # BUG NEED TO COMPARE ALL PAIRS OF FIRST 6 TOP EIGEN MODES 
for k,[k1,k2] in enumerate(pairs):
    plt.subplot(2,2,k+1)
    sca.figUnits(U[:,k1], U[:,k2], phylo) 
    plt.xlabel(r"$IC_{seq}^{%i}$"%(k1+1), fontsize=16)
    plt.ylabel(r"$IC_{seq}^{%i}$"%(k2+1), fontsize=16)

# %%
# plot histogram of each IC

independentComponents = Dsect['Vpica']
for k in range(Dsect['kpos']): #iterate through each significant IC 
    
    # determine number of bins for the histogram based on interquartile range
    iqr = stats.scoreatpercentile(independentComponents[:,k],75) - stats.scoreatpercentile(independentComponents[:,k],25)
    binWidth = 2*iqr*(len(independentComponents[:,k])**(-0.33))
    nBins = int(round((max(independentComponents[:,k]) - min(independentComponents[:,k]))/binWidth))

    #plot histogram of values in each IC
    plt.figure()
    h_params = plt.hist(independentComponents[:,k], nBins,color = 'navy')
        #output of histogram are the height of each bin and their x-positions 
    
    # plot t-distribution of each IC 
    x_dist = np.linspace(min(h_params[1]), max(h_params[1]), num=100)
    plt.plot(x_dist,Dsect['scaled_pd'][k],'r',linewidth = 2)  


    # plot defined significance cut-off 
    plt.plot([Dsect['cutoff'][k],Dsect['cutoff'][k]],[0,max(h_params[0])+10],'--m',linewidth = 3)
    plt.title('IC'+str(k+1))
    plt.ylabel('number of positions')
    plt.xlabel('$\~{V}^P_%i$'%(k+1),fontsize=20)

# %%
'+'.join([str(Dseq['ats'][s]) for s in sort_ipos])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_292/763367740.py in <module>
# ----> 1 '+'.join([str(Dseq['ats'][s]) for s in sort_ipos])
#
# NameError: name 'sort_ipos' is not defined

# %%
for n,ipos in enumerate(Dsect['ics']):
    sort_ipos = sorted(ipos.items)
    ats_ipos = ([str(Dseq['ats'][s]) for s in sort_ipos])
    ic_pymol = ('+'.join(ats_ipos))
    print('IC %i is composed of %i positions:' % (n+1,len(ats_ipos)))
    print(ic_pymol + "\n")
# Out:
# IC 1 is composed of 16 positions:
# 13+14+51+52+91+120+123+133+135+145+149+152+153+154+158+160
#
# IC 2 is composed of 15 positions:
# 53+59+80+140+146+150+157+176+178+184+201+206+207+217+225
#
# IC 3 is composed of 17 positions:
# 24+28+55+58+62+66+68+130+138+141+142+151+185+196+200+209+247
#
# IC 4 is composed of 9 positions:
# 8+27+98+114+115+143+159+208+220
#
# IC 5 is composed of 0 positions:
#
#
# IC 6 is composed of 12 positions:
# 15+17+57+63+71+126+127+128+136+137+147+214
#
# IC 7 is composed of 2 positions:
# 102+193
#
# IC 8 is composed of 11 positions:
# 10+11+16+20+21+25+65+84+161+162+204
#
# IC 9 is composed of 14 positions:
# 60+75+131+132+174+183+188+189+191+192+199+203+205+224

# %%
plt.rcParams['figure.figsize'] = 8,8
plt.figure()
plt.imshow(Dsca['Csca'][np.ix_(Dsect['sortedpos'], Dsect['sortedpos'])], \
           vmin=0, vmax=2,cmap = 'jet',interpolation='none',\
           aspect='equal',extent=[0,sum(Dsect['icsize']),\
                                  0,sum(Dsect['icsize'])])
line_index=0
for i in range(Dsect['kpos']):
    plt.plot([line_index+Dsect['icsize'][i],line_index+Dsect['icsize'][i]],\
             [0,sum(Dsect['icsize'])],'w', linewidth = 2)
    plt.plot([0,sum(Dsect['icsize'])],[sum(Dsect['icsize'])-\
            line_index,sum(Dsect['icsize'])-line_index],'w', linewidth = 2)
    line_index += Dsect['icsize'][i] 
#plt.title('Positional correlations by contribution to top ICs',fontweight='bold')
plt.colorbar()
#plt.savefig('fig_dhfr_icsHeatmap.pdf',fmt = 'pdf')

# %%
# make graph of y=n,x=n-1 for all k1+k2 in pairs (EVs in EV pairs, should be 9 EV pairs)
plt.rcParams['figure.figsize'] = 24, 21
pairs = [[i,i+1] for i in range(floor(Dsect['kpos']))]
EVs = Dsect['Vsca']
ICs = Dsect['Vpica']
for k,[k1,k2] in enumerate(pairs):
    plt.subplot(5,4,k+1)
    plt.plot(EVs[:,k1], EVs[:,k2], 'ok')
    plt.xlabel("EV%i"%(k1+1), fontsize=16)
    plt.ylabel("EV%i"%(k2+1), fontsize=16)
    if(k2<=8):
        plt.subplot(5,4,k+10)
        plt.plot(ICs[:,k1], ICs[:,k2], 'ok')
        plt.xlabel("IC%i"%(k1+1), fontsize=16)
        plt.ylabel("IC%i"%(k2+1), fontsize=16)
plt.tight_layout()

# %%
#plot the SCA positional correlation matrix, ordered by contribution to the top ICs
plt.rcParams['figure.figsize'] = 9, 9
plt.subplot(121)
plt.imshow(Dsca['Csca'][np.ix_(Dsect['sortedpos'], Dsect['sortedpos'])], \
           vmin=0, vmax=2.2,interpolation='none',\
           aspect='equal',extent=[0,sum(Dsect['icsize']),\
                                  0,sum(Dsect['icsize'])])
line_index=0
for i in range(Dsect['kpos']):
    plt.plot([line_index+Dsect['icsize'][i],line_index+Dsect['icsize'][i]],\
             [0,sum(Dsect['icsize'])],'w', linewidth = 2)
    plt.plot([0,sum(Dsect['icsize'])],[sum(Dsect['icsize'])-\
            line_index,sum(Dsect['icsize'])-line_index],'w', linewidth = 2)
    line_index += Dsect['icsize'][i]

#define the new sector groupings - 3 total
inSector =[0,1,2]
notSector =[3,4,5]

sec_groups = (inSector, notSector)
sectors = list()
c = [0.66, 0]
for n,k in enumerate(sec_groups):
    s = sca.Unit()
    all_items = list()
    all_Vp = list()
    for i in k:
        all_items = all_items+Dsect['ics'][i].items
        all_Vp = all_Vp+list(Dsect['ics'][i].vect)
    svals = np.argsort(all_Vp)
    s.items = [all_items[i] for i in svals]
    s.col = c[n]
    sectors.append(s)

#plot the re-ordered matrix
plt.subplot(122)
line_index=0
sortpos = list()
for s in sectors:
    sortpos.extend(s.items)
plt.imshow(Dsca['Csca'][np.ix_(sortpos, sortpos)], vmin=0, vmax=2.2,\
           interpolation='none',aspect='equal',\
           extent=[0,len(sortpos),0,len(sortpos)])
for s in sectors:
    plt.plot([line_index+len(s.items),line_index+len(s.items)],\
             [0,len(sortpos)],'w', linewidth = 2)
    plt.plot([0,sum(Dsect['icsize'])],[len(sortpos)-line_index,\
                    len(sortpos)-line_index],'w', linewidth = 2)
    line_index += len(s.items)
plt.tight_layout()

# %%
for i,el in enumerate(Dseq['ats']):
    Dseq['ats'][i] = str(el)
for i,k in enumerate(sectors):
    sort_ipos = sorted(k.items)
    ats_ipos = ([Dseq['ats'][s] for s in sort_ipos])
    ic_pymol = ('+'.join(ats_ipos))
    print('Sector %i is composed of %i positions:' % (i+1,len(ats_ipos)))
    print(ic_pymol + "\n")
sca.writePymol('5P21', sectors, Dsect['ics'], Dseq['ats'], \
               '/home/bjohnson/rdb/notebooks/Insig1/PF00071.pml','A', '../Inputs/', 0)
# Out:
# Sector 1 is composed of 48 positions:
# 13+14+24+28+51+52+53+55+58+59+62+66+68+80+91+120+123+130+133+135+138+140+141+142+145+146+149+150+151+152+153+154+157+158+160+176+178+184+185+196+200+201+206+207+209+217+225+247
#
# Sector 2 is composed of 21 positions:
# 8+15+17+27+57+63+71+98+114+115+126+127+128+136+137+143+147+159+208+214+220

# %%
# make graph of y=n,x=n-1 for all k1+k2 in pairs (ICs in IC pairs, should be 9 IC pairs)
plt.rcParams['figure.figsize'] = 14, 10
pairs = [[i,i+1] for i in range(floor(Dsect['kpos']))]
for n,[k1,k2] in enumerate(pairs):
    if(k2<=8):
        plt.subplot(5,4,n+1)
        sca.figUnits(Dsect['Vpica'][:,k1], Dsect['Vpica'][:,k2], \
                     sectors, dotsize = 6)
        plt.xlabel('IC%i' % (k1+1), fontsize=16)
        plt.ylabel('IC%i' % (k2+1), fontsize=16)
        plt.subplot(5,4,n+10)
        sca.figUnits(Dsect['Upica'][:,k1], Dsect['Upica'][:,k2], \
                     phylo, dotsize = 6)
        plt.xlabel(r'$U^p_{%i}$' % (k1+1), fontsize=16)
        plt.ylabel(r'$U^p_{%i}$' % (k2+1), fontsize=16)
plt.tight_layout()

# %%
plt.rcParams['figure.figsize'] = 15, 4


col = list()
for k in phylo:
    col = col + [colorsys.hsv_to_rgb(k.col,1,1)]
for k in range(Dsect['kpos']):
    forhist = list()
    for group in phylo:
        forhist.append([Dsect['Upica'][i,k] for i in group.items])
    plt.subplot(2,Dsect['kpos'],k+5)
    plt.hist(forhist, histtype='barstacked',color=col)
    plt.xlabel(r'$U^p_{%i}$' % (k+1), fontsize=16)

col = list()
for k in phylo:
    col = col + [colorsys.hsv_to_rgb(k.col,1,1)]
for k in range(Dsect['kpos']):
    forhist = list()
    for group in phylo:
        forhist.append([Dsect['Upica'][i,k] for i in group.items])
    plt.subplot(2,Dsect['kpos'],k+1)
    plt.hist(forhist, histtype='barstacked',color=col)
